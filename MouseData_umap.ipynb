# %% [markdown]
# # Umap dei geni marker del dataset di topo

# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 3             
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.8.2 anndata==0.7.5 umap==0.5.2 numpy==1.20.3 scipy==1.7.1 pandas==1.3.4 scikit-learn==1.0.1 statsmodels==0.13.1 python-igraph==0.9.8 louvain==0.7.0 pynndescent==0.5.5

# %%
adata=sc.read_h5ad('./write/MouseDataUmap.h5ad')

# %% [markdown]
# ## Colorazione della umap secondo i marker dei cluster

# %%
sc.pl.umap(adata, color=['Ptprc']) #immune cells marker genes

# %%
sc.pl.umap(adata, color=['Cd34']) #stem cells marker genes

# %%
sc.pl.umap(adata, color=['Cd3d']) #t cells marker genes

# %%
sc.pl.umap(adata, color=['Cd3e']) #t cells marker genes

# %%
sc.pl.umap(adata, color=['Klrb1c']) #nk cells marker genes

# %%
sc.pl.umap(adata, color=['Nkg7']) #nk cells marker genes

# %%
sc.pl.umap(adata, color=['Cd19']) #b cells marker genes

# %%
#sc.pl.umap(adata, color=['Cd79']) #b cells marker genes

# %%
sc.pl.umap(adata, color=['Ly6c2']) #monocytes marker genes

# %%
sc.pl.umap(adata, color=['Vcan']) #monocytes marker genes

# %%
sc.pl.umap(adata, color=['Csf1r']) #monocytes marker genes

# %%
sc.pl.umap(adata, color=['Cd68']) #macrophages marker genes

# %%
sc.pl.umap(adata, color=['Ear2']) #macrophages marker genes

# %%
sc.pl.umap(adata, color=['Ear2']) #macrophages marker genes

# %%
sc.pl.umap(adata, color=['Batf3']) #dc marker genes

# %%
sc.pl.umap(adata, color=['Fscn1']) #dc marker genes

# %%
sc.pl.umap(adata, color=['Ccr7']) #dc marker genes

# %%
sc.pl.umap(adata, color=['Col3a1']) #fibroblasts marker genes

# %%
sc.pl.umap(adata, color=['Col1a2']) #fibroblasts marker genes

# %%
sc.pl.umap(adata, color=['Col1a1']) #fibroblasts marker genes

# %%
sc.pl.umap(adata, color=['Epcam']) #epithelial cells marker genes

# %%
sc.pl.umap(adata, color=['Krt8']) #epithelial cells marker genes

# %%
sc.pl.umap(adata, color=['Krt18']) #epithelial cells marker genes

# %%
sc.pl.umap(adata, color=['S100a8']) #neutrophilis marker genes

# %%
sc.pl.umap(adata, color=['S100a9']) #neutrophilis marker genes

# %%
sc.pl.umap(adata, color=['Csf3r']) #neutrophilis marker genes
