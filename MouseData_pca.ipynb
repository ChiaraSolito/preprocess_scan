# %% [markdown]
# # Analisi della PCA sui marker nel dataset di topo

# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 3             
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.8.2 anndata==0.7.5 umap==0.5.2 numpy==1.20.3 scipy==1.7.1 pandas==1.3.4 scikit-learn==1.0.1 statsmodels==0.13.1 python-igraph==0.9.8 louvain==0.7.0 pynndescent==0.5.5

# %%
adata=sc.read_h5ad('./write/MouseDataPca.h5ad')

# %% [markdown]
# ## PCA con i geni più significativi dei cluster
# Provo a effettuare PCA con colorazione dei geni più significativi dei diversi cluster del dataset

# %% [markdown]
# Marker genes del cluster Immune Cells

# %%
sc.pl.pca(adata, color='Ptprc')

# %% [markdown]
# Marker genes del cluster Stem Cells

# %%
sc.pl.pca(adata, color='Cd34')

# %% [markdown]
# Marker genes del cluster T Cells

# %%
sc.pl.pca(adata, color='Cd3d')

# %%
sc.pl.pca(adata, color='Cd3e')

# %%
sc.pl.pca(adata, color='Cd8a')

# %% [markdown]
# Marker genes del cluster NK cells

# %%
sc.pl.pca(adata, color='Klrb1c')

# %%
sc.pl.pca(adata, color='Nkg7')

# %%
sc.pl.pca(adata, color='Gzma')

# %% [markdown]
# Marker genes del cluster B Cells

# %%
sc.pl.pca(adata, color='Cd19')

# %%
sc.pl.pca(adata, color='Cd79a')

# %% [markdown]
# Marker genes del cluster Monocytes

# %%
sc.pl.pca(adata, color='Ly6c2')

# %%
sc.pl.pca(adata, color='Vcan')

# %%
sc.pl.pca(adata, color='Csf1r')

# %% [markdown]
# Marker genes del cluster Macrophages

# %%
sc.pl.pca(adata, color='Cd68')

# %%
sc.pl.pca(adata, color='Ear2')

# %% [markdown]
# Marker genes del cluster DC

# %%
sc.pl.pca(adata, color='Batf3')

# %%
sc.pl.pca(adata, color='Fscn1')

# %% [markdown]
# Marker genes del cluster Fibroblast

# %%
sc.pl.pca(adata, color='Col3a1')

# %%
sc.pl.pca(adata, color='Col1a2')

# %% [markdown]
# Marker genes del cluster cellule epiteliali

# %%
sc.pl.pca(adata, color='Epcam')

# %%
sc.pl.pca(adata, color='Krt8')

# %% [markdown]
# Marker genes del cluster neutrofili

# %%
sc.pl.pca(adata, color='S100a8')

# %%
sc.pl.pca(adata, color='S100a9')
